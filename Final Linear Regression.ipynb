# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
final = pd.read_csv("/Users/mdbarshay/Desktop/401/Project 3/final.csv", index_col = 0)

# %%
X = final.iloc[:, :50]
y = final.iloc[:,50]

# %%
X = (X-X.mean())/X.std()
y = y / 100000

# %%
lm = linear_model.LinearRegression()
res = cross_val_score(lm, X, y, scoring = "neg_mean_squared_error", cv = 5)
res2 = cross_val_score(lm, X, y, scoring = "neg_root_mean_squared_error", cv = 5)
res3 = cross_val_score(lm, X, y, scoring = "r2", cv = 5)

# %% [markdown]
# The average mean squared error for 5-fold cross validated linear regression is:

# %%
-np.mean(res)
# Out:
# 2817.7455042857882

# %% [markdown]
# The average root mean squared error for 5-fold cross validated linear regression is:

# %%
-np.mean(res2)
# Out:
# 48.17603766774928

# %% [markdown]
# The average R^2 for 5-fold cross validated linear regression is:

# %%
-np.mean(res3)
# Out:
# 0.33871622420764114

# %% [markdown]
# This means that on average our predictions for median house price are roughly 4,800,000 dollars away from the true house price on average. Furthermore, our linear regression model explains around 33.87% of the variance in house prices.

# %% [markdown]
# We are only using this model for predictions and not interpreting the coefficients and so checking the model assumptions is not neccesary.

# %%
final
# Out:
#        num_room  full_sq  sport_count_5000  sport_count_3000  trc_count_5000  \
# 0      1.962264       43                52                21              52
# 1      1.925926       34                66                19              40
# 2      1.858586       43                67                20              35
# 3      2.132275       89                26                18              22
# 4      2.875000       77               195                77             114
# ...         ...      ...               ...               ...             ...
# 30287  2.000000       44                84                29              53
# 30288  4.000000       86               171                80              90
# 30289  1.000000       45                11                 6               4
# 30290  2.000000       64                65                33              45
# 30291  2.000000       43                54                26              22
#
# ...
